# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import autorootcwd
import json
import os
import pandas as pd

# %%
DIR = './results/generative_features'
expts = os.listdir(DIR)
rows = []
for e in expts:
    with open(f"{DIR}/{e}/metadata.json") as f:
        args = json.load(f)

    args = args['args']
    reduction = args['gen_reduction']
    model_name = args['gen_model_name']

    if not os.path.exists(f"{DIR}/{e}/val_metrics.json"):
        print(f"Skipping {e} because val_metrics.json does not exist")
        continue
    
    with open(f"{DIR}/{e}/val_metrics.json") as f:
        data = json.load(f)

        rows.append({
            'reduction': reduction,
            'model_name': model_name,
            'accuracy': data['mean']['acc'],
            'root': data['mean']['root'],
            'majmin': data['mean']['majmin'],
            'third': data['mean']['third'],
            'seventh': data['mean']['seventh'],
            'mirex': data['mean']['mirex'],
            'mean_acc_class': data['class_wise']['acc']['mean'],
            'median_acc_class': data['class_wise']['acc']['median'],
            'avg_transitions': data['avg_transitions_per_song']
        })
 

df = pd.DataFrame(rows)
# Out:
# Skipping model_large_reduction_concat because val_metrics.json does not exist
# Skipping model_chord_reduction_concat because val_metrics.json does not exist
# Skipping model_melody_reduction_concat because val_metrics.json does not exist
# Skipping model_small_reduction_concat because val_metrics.json does not exist
# Skipping model_large-conditioned_reduction_concat because val_metrics.json does not exist
# Skipping model_large-lerp_reduction_concat because val_metrics.json does not exist

# %%
df.sort_values(by=['accuracy'], inplace=True, ascending=False)
df
# Out:
#      reduction         model_name   accuracy       root     majmin      third  \
# 6   codebook_3              large  61.985559  80.761905  78.467802  77.792180
# 23  codebook_3  large-conditioned  61.985559  80.761905  78.467802  77.792180
# 29  codebook_3              chord  61.825302  80.480337  78.228000  77.552548
# 2   codebook_3              small  61.803988  80.610941  78.324663  77.696051
# 26  codebook_3         large-lerp  61.781139  80.506585  78.210872  77.557239
# 7   codebook_1  large-conditioned  61.689168  80.959410  78.514416  77.864577
# 16  codebook_1              large  61.689168  80.959410  78.514416  77.864577
# 14  codebook_1         large-lerp  61.671034  80.805510  78.385782  77.738151
# 18  codebook_3             melody  61.616184  80.203767  77.996412  77.300416
# 5   codebook_1             melody  61.594660  80.807978  78.445973  77.817341
# 3   codebook_2              large  61.567703  80.614489  78.194014  77.519028
# 22  codebook_2  large-conditioned  61.567703  80.614489  78.194014  77.519028
# 21  codebook_1              small  61.551997  80.576676  78.129619  77.502327
# 12  codebook_0         large-lerp  61.359620  80.658451  77.988352  77.319636
# 28  codebook_2         large-lerp  61.289464  80.350415  77.854285  77.186355
# 27  codebook_2              chord  61.269601  80.639775  77.886351  77.207061
# 11  codebook_1              chord  61.252755  80.511837  77.756709  77.136531
# 20  codebook_2             melody  61.243231  80.188057  77.717705  77.056359
# 24         avg              chord  61.115769  80.378303  77.735856  77.011047
# 13  codebook_0              chord  61.104241  80.189028  77.399503  76.801609
# 15         avg             melody  60.959039  80.121847  77.647898  76.950612
# 4   codebook_2              small  60.950524  80.525644  77.736120  77.078074
# 0          avg         large-lerp  60.932383  80.199085  77.640540  76.958268
# 9          avg              small  60.878554  80.160934  77.581917  76.911255
# 25         avg              large  60.796828  80.185587  77.609536  76.907419
# 8          avg  large-conditioned  60.796828  80.185587  77.609536  76.907419
# 19  codebook_0              large  60.606656  80.312433  77.478879  76.857794
# 10  codebook_0  large-conditioned  60.606656  80.312433  77.478879  76.857794
# 17  codebook_0              small  60.494608  80.154095  77.383104  76.791185
# 1   codebook_0             melody  60.485645  80.262090  77.644927  77.041665
#
#       seventh      mirex  mean_acc_class  median_acc_class  avg_transitions
# 6   64.288605  80.523075       20.754083          3.924757       102.634855
# 23  64.288605  80.523075       20.754083          3.924757       102.634855
# 29  64.138608  80.287666       19.845218          2.165393       102.850622
# 2   64.112353  80.383971       20.307953          2.747232       103.468880
# 26  64.065555  80.540181       20.705509          4.051362       103.145228
# 7   64.021793  80.972317       20.803864          2.794672       102.240664
# 16  64.021793  80.972317       20.803864          2.794672       102.240664
# 14  63.995371  81.152744       20.708033          3.478616       102.796680
# 18  63.915522  80.221071       20.541351          3.577851       101.622407
# 5   63.926638  80.406155       20.814459          2.865711       102.717842
# 3   63.886604  80.580128       20.504052          2.573042       103.004149
# 22  63.886604  80.580128       20.504052          2.573042       103.004149
# 21  63.909206  80.589339       20.519835          3.882606       102.850622
# 12  63.661024  80.542300       20.178972          0.914111       100.053942
# 28  63.597415  80.818245       20.405992          1.772471       103.049793
# 27  63.551512  80.451556       20.323587          1.578786       103.975104
# 11  63.559253  80.843865       20.729008          2.356528       103.178423
# 20  63.515483  80.455120       20.787240          3.525857       102.107884
# 24  63.402591  79.688551       19.589758          0.000000       102.219917
# 13  63.411360  80.283924       20.324042          1.101402       102.589212
# 15  63.269623  80.054235       20.047538          0.808214       102.834025
# 4   63.205233  80.382180       20.392748          1.683235       104.298755
# 0   63.218786  80.342026       19.893705          0.881218       102.937759
# 9   63.158298  80.091993       19.801279          0.675597       103.381743
# 25  63.081207  80.294607       19.811524          0.769879       102.759336
# 8   63.081207  80.294607       19.811524          0.769879       102.759336
# 19  62.900103  80.546902       20.282240          2.096679       100.792531
# 10  62.900103  80.546902       20.282240          2.096679       100.792531
# 17  62.806656  80.386597       20.113592          1.101402       101.697095
# 1   62.798896  80.296320       20.320273          1.101402       101.489627

# %%
df[df['model_name'].isin(["melody", "chord"])]
# Out:
#      reduction model_name   accuracy       root     majmin      third  \
# 29  codebook_3      chord  61.825302  80.480337  78.228000  77.552548
# 18  codebook_3     melody  61.616184  80.203767  77.996412  77.300416
# 5   codebook_1     melody  61.594660  80.807978  78.445973  77.817341
# 27  codebook_2      chord  61.269601  80.639775  77.886351  77.207061
# 11  codebook_1      chord  61.252755  80.511837  77.756709  77.136531
# 20  codebook_2     melody  61.243231  80.188057  77.717705  77.056359
# 24         avg      chord  61.115769  80.378303  77.735856  77.011047
# 13  codebook_0      chord  61.104241  80.189028  77.399503  76.801609
# 15         avg     melody  60.959039  80.121847  77.647898  76.950612
# 1   codebook_0     melody  60.485645  80.262090  77.644927  77.041665
#
#       seventh      mirex  mean_acc_class  median_acc_class  avg_transitions
# 29  64.138608  80.287666       19.845218          2.165393       102.850622
# 18  63.915522  80.221071       20.541351          3.577851       101.622407
# 5   63.926638  80.406155       20.814459          2.865711       102.717842
# 27  63.551512  80.451556       20.323587          1.578786       103.975104
# 11  63.559253  80.843865       20.729008          2.356528       103.178423
# 20  63.515483  80.455120       20.787240          3.525857       102.107884
# 24  63.402591  79.688551       19.589758          0.000000       102.219917
# 13  63.411360  80.283924       20.324042          1.101402       102.589212
# 15  63.269623  80.054235       20.047538          0.808214       102.834025
# 1   62.798896  80.296320       20.320273          1.101402       101.489627

# %%
df[df['model_name'] == 'large']
# Out:
#      reduction model_name   accuracy       root     majmin      third  \
# 6   codebook_3      large  61.985559  80.761905  78.467802  77.792180
# 16  codebook_1      large  61.689168  80.959410  78.514416  77.864577
# 3   codebook_2      large  61.567703  80.614489  78.194014  77.519028
# 25         avg      large  60.796828  80.185587  77.609536  76.907419
# 19  codebook_0      large  60.606656  80.312433  77.478879  76.857794
#
#       seventh      mirex  mean_acc_class  median_acc_class  avg_transitions
# 6   64.288605  80.523075       20.754083          3.924757       102.634855
# 16  64.021793  80.972317       20.803864          2.794672       102.240664
# 3   63.886604  80.580128       20.504052          2.573042       103.004149
# 25  63.081207  80.294607       19.811524          0.769879       102.759336
# 19  62.900103  80.546902       20.282240          2.096679       100.792531

# %%
DIR = './results/gen_down_dim'
expts = os.listdir(DIR)
rows = []
for e in expts:
    with open(f"{DIR}/{e}/metadata.json") as f:
        args = json.load(f)

    args = args['args']
    reduction = args['gen_reduction']
    model_name = args['gen_model_name']
    dim = args['gen_down_dimension']

    if not os.path.exists(f"{DIR}/{e}/val_metrics.json"):
        print(f"Skipping {e} because val_metrics.json does not exist")
        continue
    
    with open(f"{DIR}/{e}/val_metrics.json") as f:
        data = json.load(f)

        rows.append({
            'reduction': reduction,
            'model_name': model_name,
            'dim': dim,
            'accuracy': data['mean']['acc'],
            'root': data['mean']['root'],
            'majmin': data['mean']['majmin'],
            'third': data['mean']['third'],
            'seventh': data['mean']['seventh'],
            'mirex': data['mean']['mirex'],
            'mean_acc_class': data['class_wise']['acc']['mean'],
            'median_acc_class': data['class_wise']['acc']['median'],
            'avg_transitions': data['avg_transitions_per_song']
        })
 

df = pd.DataFrame(rows)

# %%
df.sort_values(by=['root'], inplace=True, ascending=False)
df
# Out:
#     reduction model_name   dim   accuracy       root     majmin      third  \
# 0  codebook_3      large    64  61.043626  80.390140  77.646594  77.028222
# 4  codebook_3      large    32  60.631919  80.129841  77.363522  76.699808
# 1  codebook_3      large   256  60.529899  79.951082  77.322563  76.556654
# 5  codebook_3      large    16  60.807803  79.847501  77.396422  76.692022
# 2  codebook_3      large   128  59.635996  79.134021  76.504156  75.890263
# 6  codebook_3      large   512  59.662792  78.924632  76.330498  75.553907
# 3  codebook_3      large  1024  60.162922  78.730608  76.405702  75.792933
#
#      seventh      mirex  mean_acc_class  median_acc_class  avg_transitions
# 0  63.370496  78.930160       18.731251          1.312397        99.640496
# 4  62.903671  79.715731       19.658294          1.041908       102.152893
# 1  62.732719  79.474035       20.142654          1.012670        99.359504
# 5  63.098674  80.070402       20.007490          2.129280       100.322314
# 2  61.959424  78.827607       18.164376          0.000000        98.475207
# 6  62.018192  79.631131       18.847356          1.930173        99.677686
# 3  62.404155  77.147287       18.352209          0.000000        97.516529
