# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import autorootcwd
import torch
import os
import numpy as np
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from torch.utils.data.dataloader import DataLoader
from sklearn.metrics import confusion_matrix

from src.utils import id_to_chord_map, get_torch_device, collate_fn, get_annotation_metadata, get_split_filenames, get_chord_root
from src.models.ismir2017 import ISMIR2017ACR
from src.data.dataset import FullChordDataset

# %% [markdown]
# # Basics
#
# ### Get the model

# %%
DIR = './results/small_vs_large_vocab/small_vocab_defaults'

device = get_torch_device()
model = ISMIR2017ACR(cr2=False, num_classes=26)
model.load_state_dict(torch.load(f'{DIR}/best_model.pth', map_location=device, weights_only=True))
model.eval()
# Out:
# ISMIR2017ACR(
#   (batch_norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (activation1): ReLU()
#   (conv2): Conv2d(1, 36, kernel_size=(1, 216), stride=(1, 1))
#   (activation2): ReLU()
#   (bi_gru_encoder): GRU(36, 256, batch_first=True, bidirectional=True)
#   (dense): Linear(in_features=512, out_features=26, bias=True)
# )

# %% [markdown]
# ### Run the Model

# %%
_, val_filenames, _ = get_split_filenames()

dataset = FullChordDataset(filenames=val_filenames, small_vocab=True)

dataset[0][1].shape
# Out:
# torch.Size([4473])

# %%
all_preds = []
all_labels = []

with torch.no_grad():  # Use no_grad to speed up inference
    for i in tqdm(range(len(dataset))):
        cqt, label = dataset[i]
        pred = model(cqt.unsqueeze(0))
        preds = torch.argmax(pred, dim=2)
        all_preds.append(preds[0])  # Keep as tensors
        all_labels.append(label)    # Keep as tensors

# Concatenate all predictions and labels at the end
all_preds = torch.cat(all_preds)
all_labels = torch.cat(all_labels)
# Out:
# 100%|██████████| 242/242 [00:55<00:00,  4.39it/s]

# %% [markdown]
# ### Overall Accuracy

# %%
# Overall accuracy
from sklearn.metrics import accuracy_score
accuracy_score(all_labels, all_preds)
# Out:
# 0.7166763150919971

# %%
len(id_to_chord_map)
# Out:
# 26

# %% [markdown]
# ### Confusion Matrices

# %%
# Compute confusion matrix and normalized confusion matrix
cm = confusion_matrix(all_labels, all_preds, labels=range(len(id_to_chord_map)))
cm_normalized = cm.astype('float') / cm.sum(axis=1, keepdims=True)

# Reorder the confusion matrix based on the diagonal terms
order = np.argsort(-np.diag(cm))  # Sort indices in descending order
order_normalized = np.argsort(np.diag(cm_normalized))  # Sort indices in descending order

# Reorder the confusion matrix
cm = cm[order][:, order]
cm_normalized = cm_normalized[order_normalized][:, order_normalized]

# Map IDs to chord labels
chord_labels = [id_to_chord_map[id] for id in order]
chord_labels_normalized = [id_to_chord_map[id] for id in order_normalized]

# Plot the confusion matrices
fig, axes = plt.subplots(2, 1, figsize=(12, 20))

# Raw confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=chord_labels, 
            yticklabels=chord_labels, ax=axes[0], cbar=True, annot_kws={"fontsize": 6}, square=True)
axes[0].set_title("Raw Confusion Matrix", fontsize=18)
axes[0].set_xlabel('Predicted Label', fontsize=14)
axes[0].set_ylabel('True Label', fontsize=14)

# Normalized confusion matrix
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=chord_labels_normalized, 
            yticklabels=chord_labels_normalized, ax=axes[1], cbar=True, annot_kws={"fontsize": 6})
axes[1].set_title("Normalized Confusion Matrix", fontsize=18)
axes[1].set_xlabel('Predicted Label', fontsize=14)
axes[1].set_ylabel('True Label', fontsize=14)

plt.tight_layout()
plt.show()

# %%
#  Map chord IDs to chord roots
all_labels_root = [get_chord_root(id.item()) for id in all_labels]
all_preds_root = [get_chord_root(id.item()) for id in all_preds]

# %%
# Get unique roots and map them to indices
unique_roots = sorted(set(all_labels_root + all_preds_root))
root_to_id = {root: i for i, root in enumerate(unique_roots)}
id_to_root = {i: root for i, root in enumerate(unique_roots)}

# Convert roots to indices for confusion matrix computation
labels_root_idx = [root_to_id[root] for root in all_labels_root]
preds_root_idx = [root_to_id[root] for root in all_preds_root]

# Compute confusion matrix and normalized confusion matrix
cm_root = confusion_matrix(labels_root_idx, preds_root_idx, labels=range(len(unique_roots)))
cm_root_normalized = cm_root.astype('float') / cm_root.sum(axis=1, keepdims=True)

# Reorder both confusion matrices in descending order of diagonal values
order_root = np.argsort(-np.diag(cm_root))  # Raw matrix order
order_root_normalized = np.argsort(-np.diag(cm_root_normalized))  # Normalized matrix order

# Reorder the confusion matrices
cm_root_reordered = cm_root[order_root][:, order_root]
cm_root_normalized_reordered = cm_root_normalized[order_root_normalized][:, order_root_normalized]

# Map reordered indices back to chord roots
root_labels_reordered = [id_to_root[id] for id in order_root]
root_labels_normalized_reordered = [id_to_root[id] for id in order_root_normalized]

# Plot the normalized confusion matrix (roots)
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(cm_root_normalized_reordered, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=root_labels_normalized_reordered, yticklabels=root_labels_normalized_reordered, 
            ax=ax, cbar=True, annot_kws={"fontsize": 6}, square=True)
ax.set_xlabel('Predicted Root', fontsize=14)
ax.set_ylabel('True Root', fontsize=14)
plt.tight_layout()
plt.savefig('report/figures/small_vocab_root_cm.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Incorrect Regions, Accuracy over Songs, Accuracy over time

# %%
import matplotlib as mpl

cmap = mpl.colors.ListedColormap(["tab:red", "tab:blue"])
bounds = [0, 0.5, 1]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

example_indices = [0, 1, 2,3,4,5,6,7]  # choose whichever you like

fig, axes = plt.subplots(nrows=len(example_indices), figsize=(12, 2 * len(example_indices)))
for ax, idx in zip(axes, example_indices):
    cqt, label = dataset[idx]
    with torch.no_grad():
        pred = model(cqt.unsqueeze(0))
        pred_classes = torch.argmax(pred, dim=2).squeeze(0)
    
    correctness = (pred_classes == label).long().numpy()
    correctness_2d = correctness[np.newaxis, :]

    ax.imshow(correctness_2d, cmap=cmap, norm=norm, aspect="auto")
    title = get_annotation_metadata(dataset.get_filename(idx))["title"]
    ax.set_title(f"Song={title}, idx={idx}, Correct={round(correctness.sum()/len(correctness),3)}", fontsize=12)
    ax.set_yticks([])
    ax.set_xticks([]) 

plt.show()

# %%
from itertools import groupby

# For accuracy histogram
all_accuracies = []

# For incorrect region analysis
incorrect_region_lengths = []
incorrect_frame_with_correct_neighbors = 0
total_incorrect_frames = 0
single_frame_regions = 0

# For average accuracy over time
max_length = max([len(dataset[idx][1]) for idx in range(len(dataset))])  # Longest song length
correctness_matrix = np.zeros((len(dataset), max_length))  # Rows: Songs, Columns: Time steps
valid_frames = np.zeros(max_length)  # To count valid entries at each time step

# Unified loop
for idx in tqdm(range(len(dataset))):
    cqt, label = dataset[idx]
    with torch.no_grad():
        pred = model(cqt.unsqueeze(0))
        pred_classes = torch.argmax(pred, dim=2).squeeze(0)
    
    correctness = (pred_classes == label).long().numpy()
    incorrect_mask = correctness == 0

    # Accuracy for the histogram
    accuracy = correctness.sum() / len(correctness)
    all_accuracies.append(accuracy)

    # Incorrect region analysis
    region_lengths = [len(list(group)) for val, group in groupby(incorrect_mask) if val]
    incorrect_region_lengths.extend(region_lengths)
    single_frame_regions += region_lengths.count(1)
    total_incorrect_frames += np.sum(incorrect_mask)
    for i in range(1, len(correctness) - 1):
        if not correctness[i] and correctness[i - 1] and correctness[i + 1]:
            incorrect_frame_with_correct_neighbors += 1

    # Average accuracy over time
    correctness_matrix[idx, :len(correctness)] = correctness
    valid_frames[:len(correctness)] += 1
# Out:
# 100%|██████████| 1213/1213 [05:14<00:00,  3.85it/s]

# %%
# Final computations and plots
percent_single_frame_regions = (single_frame_regions / len(incorrect_region_lengths)) * 100 if incorrect_region_lengths else 0
percent_incorrect_with_correct_neighbors = (incorrect_frame_with_correct_neighbors / total_incorrect_frames) * 100 if total_incorrect_frames else 0
average_accuracy_over_time = correctness_matrix.sum(axis=0) / valid_frames

# Accuracy histogram
plt.figure(figsize=(10, 6))
plt.hist(all_accuracies, bins=20, range=(0, 1), alpha=0.7, color='skyblue', edgecolor='black')
plt.title("Histogram of Accuracies Over All Songs", fontsize=14)
plt.xlabel("Accuracy", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Incorrect region histogram
plt.figure(figsize=(10, 6))
plt.hist(incorrect_region_lengths, bins=range(1, max(incorrect_region_lengths) + 2), alpha=0.7, color='salmon', edgecolor='black')
plt.title("Histogram of Incorrect Region Lengths", fontsize=14)
plt.xlabel("Length of Incorrect Region", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Average accuracy over time plot
plt.figure(figsize=(12, 6))
plt.plot(average_accuracy_over_time, marker='o', linestyle='-', alpha=0.8)
plt.title("Average Accuracy Over Time in Songs", fontsize=14)
plt.xlabel("Time Step (Frame Index)", fontsize=12)
plt.ylabel("Average Accuracy", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Print percentages
print(f"Percentage of incorrect regions that are 1 frame wide: {percent_single_frame_regions:.2f}%")
print(f"Percentage of incorrect frames with correct neighbors on both sides: {percent_incorrect_with_correct_neighbors:.2f}%")
# Out:
# Percentage of incorrect regions that are 1 frame wide: 32.20%
# Percentage of incorrect frames with correct neighbors on both sides: 4.44%

# %% [markdown]
# # Transition Frame Accuracy

# %%
from src.utils import get_chord_annotation

all_transitions = []
dataset = FullChordDataset()

for i in tqdm(range(len(dataset))):
    filename = dataset.get_filename(i)
    _, transitions = get_chord_annotation(filename, return_transitions=True, frame_length=dataset.hop_length / dataset.sr)
    _, labels = dataset[i]
    all_transitions.extend(transitions[:labels.shape[0]].tolist())

all_transitions = np.array(all_transitions)
# Out:
# 100%|██████████| 1213/1213 [00:33<00:00, 36.68it/s]

# %%
# Compute overall accuracy
overall_acc = accuracy_score(all_labels, all_preds)

# Identify which indices are transitions vs non-transitions
transition_indices = [i for i, t in enumerate(all_transitions) if t]
non_transition_indices = [i for i, t in enumerate(all_transitions) if not t]

labels_transition = [all_labels[i] for i in transition_indices]
preds_transition  = [all_preds[i] for i in transition_indices]
labels_non_transition = [all_labels[i] for i in non_transition_indices]
preds_non_transition  = [all_preds[i] for i in non_transition_indices]

transition_acc = accuracy_score(labels_transition, preds_transition)
non_transition_acc = accuracy_score(labels_non_transition, preds_non_transition)

print("Overall Accuracy:", overall_acc)
print("Transition Frames Accuracy:", transition_acc)
print("Non-Transition Frames Accuracy:", non_transition_acc)
# Out:
# Overall Accuracy: 0.7698718754852004
# Transition Frames Accuracy: 0.4727622780327643
# Non-Transition Frames Accuracy: 0.7825320390738993

# %%
# Percentage of frames that are transitions
num_transitions = sum(all_transitions)
print("Fraction of frames that are transitions:", round(num_transitions / len(all_transitions), 3))
# Out:
# Fraction of frames that are transitions: 0.041

# %%
len(all_transitions), len(all_labels), len(all_preds)
# Out:
# (2846762, 2846762, 2846762)

# %% [markdown]
# # Context Lengths
#
# ### Different Context Lengths

# %%
from src.data.dataset import FixedLengthChordDataset
from sklearn.metrics import accuracy_score

context_lengths = [5, 10, 20, 60]
accuracies = []
device = get_torch_device()
model.eval()
model.to(device)

for context_length in context_lengths:
    print(f"Context length: {context_length}")
    dataset = FixedLengthChordDataset(segment_length=context_length, cached=True)
    loader = DataLoader(dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)
    all_preds_context = []
    all_labels_context = []
    for batch_cqt, batch_labels in tqdm(loader):
        batch_cqt, batch_labels = batch_cqt.to(device), batch_labels.to(device)
        batch_preds = model(batch_cqt)
        batch_preds = torch.argmax(batch_preds, dim=2).cpu()
        all_preds_context.extend(torch.flatten(batch_preds).tolist())
        all_labels_context.extend(torch.flatten(batch_labels).tolist())

    ignore_index = -1
    mask = torch.tensor(all_labels) != ignore_index
    all_preds_context = torch.tensor(all_preds_context)[mask]
    all_labels_context = torch.tensor(all_labels_context)[mask]
    accuracy = accuracy_score(all_labels_context, all_preds_context)
    accuracies.append(accuracy)

plt.plot(context_lengths, accuracies, marker='o')
plt.xlabel('Context Length')
plt.ylabel('Accuracy')
plt.title('Context Length vs. Accuracy')
plt.grid()
plt.show()
# Out:
# Context length: 5
# 100%|██████████| 1697/1697 [04:19<00:00,  6.55it/s]
# Context length: 10
# 100%|██████████| 850/850 [04:03<00:00,  3.49it/s]
# Context length: 20
# 100%|██████████| 433/433 [03:27<00:00,  2.09it/s]
# Context length: 60
# 100%|██████████| 157/157 [03:01<00:00,  1.16s/it]

# %% [markdown]
# ### Accuracy at Edeges of Context

# %%
from src.data.dataset import FixedLengthChordDataset
from torch.utils.data.dataloader import DataLoader
from sklearn.metrics import accuracy_score
from src.utils import collate_fn

accuracies = []
device = get_torch_device()
model.eval()
model.to(device)

dataset = FixedLengthChordDataset(segment_length=10, cached=True)
loader = DataLoader(dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)
num_frames = dataset.segment_length_samples
frame_correct_counts = torch.zeros(num_frames)
frame_total_counts = torch.zeros(num_frames)

for batch_cqt, batch_labels in tqdm(loader):
    batch_cqt, batch_labels = batch_cqt.to(device), batch_labels.to(device)
    batch_preds = model(batch_cqt)
    batch_preds = torch.argmax(batch_preds, dim=2)
    correct = (batch_preds == batch_labels).cpu()
    # Mask out invalid labels (-1)
    valid_mask = batch_labels != -1  # Shape: (batch_size, num_frames)

    # Compute correctness only for valid frames
    correct = (batch_preds == batch_labels) & valid_mask  # Shape: (batch_size, num_frames)

    # Update counts
    frame_correct_counts += correct.sum(dim=0).cpu()  # Count of correct predictions per frame
    frame_total_counts += valid_mask.sum(dim=0).cpu()  # Count of valid frames per frame
# Out:
# 100%|██████████| 850/850 [03:53<00:00,  3.64it/s]

# %% [markdown]
# ### Frame-wise accuracies

# %%
# Compute average accuracy per frame
frame_accuracies = frame_correct_counts / frame_total_counts

# Plot the results
import matplotlib.pyplot as plt

frames = torch.arange(num_frames)
plt.figure(figsize=(10, 6))
plt.plot(frames, frame_accuracies, marker='o')
plt.title("Average Frame-wise Accuracy", fontsize=16)
plt.xlabel("Frame Index", fontsize=14)
plt.ylabel("Average Accuracy", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Training run loss Graphs

# %%
import json

for exp in os.listdir('./data/experiments/'):
    if not os.path.exists(f'./data/experiments/{exp}/training_history.json'):
        continue
    training_history = json.load(open(f'./data/experiments/{exp}/training_history.json'))
    train_losses = training_history['train_losses']
    val_losses = training_history['val_losses']
    val_accuracies = training_history['val_accuracies']
    # Plot all 3, with acc having its own y-axis
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(train_losses, label='Training Loss', color='blue')
    ax1.plot(val_losses, label='Validation Loss', color='orange')
    ax2.plot(val_accuracies, label='Validation Accuracy', color='green')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax2.set_ylabel('Accuracy')
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')
    plt.title(f'Loss and Accuracy for {exp}')

# %% [markdown]
# # Listening!

# %%
from src.utils import get_filenames

# %%
filenames = get_filenames()
filenames
# Out:
# ['bobseger_rockandrollneverforgets(live)',
#  'blessidunionofsouls_ibelieve',
#  'robertjohn_lonelyeyes',
#  'foreigner_iwanttoknowwhatloveis',
#  'ericburdonandtheanimals_sanfranciscannights',
#  'thebeatles_thecontinuingstoryofbungalowbill',
#  'andygibb_shadowdancing',
#  "heart_there'sthegirl(2000digitalremaster)",
#  'the5thdimension_gowhereyouwannago',
#  'davidbowie_modernlove(singleversion)(2002digitalremaster)',
#  'gregkihn_happyman(live)',
#  'blondie_onewayoranother',
#  'bobseger_nightmoves(albumversion)',
#  'thebeatles_youlikemetoomuch',
#  'tevincampbell_tellmewhatyouwantmetodo(single)',
#  'TRLBPGI149E33BDA3C',
#  'johnnyhorton_johnnyreb',
#  'thebeatles_goodmorninggoodmorning',
#  'billyjoel_aninnocentman',
#  'jamesbrown_getupifeellikebeingasexmachine',
#  'donovan_sunshinesuperman(fullversion)(1998digitalremaster)',
#  'leannrimes_ineedyou',
#  'steviewonder_higherground',
#  'otisredding_chainedandbound',
#  'eagles_thelongrun',
#  'thebeatles_abbeyroadmedley(full)',
#  'TRKLGWQ149E3E580CD',
#  'steviewonder_doido',
#  'thebeatles_happinessisawarmgun',
#  "thebeatles_everybody'stryingtobemybaby",
#  'queen_crazylittlethingcalledlove',
#  'blink182_mutt',
#  'louisprima_thatoldblackmagic',
#  'buckowens_thinkofme',
#  'thepolice_messageinabottle',
#  'thebeatles_doctorrobert',
#  'roxymusic_danceaway',
#  'laurabranigan_gloria(single)',
#  'earth,wind&fire_getaway',
#  'neilsedaka_laughterintherain',
#  "thebeatles_youcan'tdothat(64)",
#  'digitalunderground_thehumptydance',
#  "meltormé_comin'homebaby",
#  'TRTCQHU149E3F02918',
#  "wilsonpickett_don'tknockmylove-part1",
#  'wham!_wakemeupbeforeyougo-go',
#  'aqua_doctorjones',
#  'shirleybrown_womantowoman',
#  'jesusjones_righthererightnow',
#  'tinaturner_whatyougetiswhatyousee',
#  'drhook_yearsfromnow',
#  'queen_friendswillbefriends',
#  'weezer_hashpipe',
#  "robertaflack_feellikemakin'love",
#  'thebeatles_younevergivemeyourmoney',
#  'jackson,janet_19again',
#  'cheaptrick_iwantyoutowantme',
#  'TRSLOFF149E35DDC54',
#  "tompetty_iwon'tbackdown",
#  'chicago_aliveagain',
#  'donmclean_vincent(starry,starrynight)',
#  'rickjames_giveittomebaby(singleversion)',
#  'queen_anotheronebitesthedust',
#  "thelmahouston_don'tleavemethisway",
#  'cannedheat_ontheroadagain',
#  'themoments_walkrightin',
#  'natkingcole_thoselazy,hazy,crazydaysofsummer(1990digitalremaster)',
#  'eltonjohn_goodbyeyellowbrickroad',
#  'randyvanwarmer_justwhenineededyoumost',
#  "tinaturner_what'slovegottodowithit",
#  "thetemptations_ain'ttooproudtobeg",
#  "otisredding_(sittin'on)thedockofthebay",
#  'madonna_ohfather',
#  'googoodolls_name',
#  'TRBFMXE149E3E18222',
#  'TRSUAVV149E3B8B57E',
#  'chicago_alongcomesawoman(singleversion)',
#  'kennyrogers_sweetmusicman',
#  'thebeatles_twistandshout(mono)',
#  'thebeatles_long,long,long',
#  'thebeatles_adayinthelife',
#  'drhook_sexyeyes',
#  'villagepeople_inthenavy',
#  'theventures_perfidia',
#  'edwinstarr_war',
#  'hall&oates_maneater',
#  'acdc_hellsbells',
#  'marx,richard_rightherewaiting',
#  'drhook_ifnotyou',
#  'theband_lifeisacarnival',
#  'jethrotull_livinginthepast',
#  'TRWKVUY149E33B5AC8',
#  'ritacoolidge_(yourlovehasliftedme)higherandhigher',
#  'robertpalmer_addictedtolove-remix',
#  'TRLMIXE149E3898756',
#  'theritchiefamily_thebestdiscointown',
#  'beck_loser',
#  'thebeatles_anothergirl',
#  'thestring-a-longs_wheels',
#  'ledzeppelin_overthehillsandfaraway',
#  "billyjoel_don'taskmewhy",
#  'algreen_ohme,ohmy(dreamsinmyarms)',
#  "tinaturner_wedon'tneedanotherhero(thunderdome)",
#  'theturtles_happytogether',
#  "thebeatles_there'saplace",
#  'freddiejackson_haveyoueverlovedsomebody',
#  'therollingstones_haveyouseenyourmother(66)',
#  'the5thdimension_nevermylove',
#  'paulsimon_50waystoleaveyourlover',
#  'heart_whowillyourunto',
#  'commodores_still(singleversion)',
#  'peggylee_fever',
#  'TRYCZIN149E2C5DC15',
#  'wilsonphillips_holdon',
#  'jacksonbrowne_redneckfriend',
#  'dion_(iwas)borntocry',
#  'heart_magicman',
#  "johnnytillotson_itkeepsrightona-hurtin'",
#  'theeverlybrothers_onthewingsofanightingale',
#  "thebeatles_i'mhappyjusttodancewithyou(64)",
#  'cream_sunshineofyourlove',
#  "thekendalls_heaven'sjustasinaway",
#  'spandauballet_true',
#  'sublime_santeria',
#  'marieosmond_paperroses',
#  'TREMNLC149E3AD6ECB',
#  'neildiamond_playme',
#  'abba_honey,honey',
#  "thebeatles_i'vegotafeeling",
#  'thebeatles_tickettoride',
#  "the5thdimension_(lastnight)ididn'tgettosleepatall",
#  'ericclapton_letitrain',
#  'thepowerstation_somelikeithot',
#  'bonniepointer_heavenmusthavesentyou',
#  'tinaturner_privatedancer(1997digitalremaster)(1997-remaster)',
#  'eltonjohn_levon',
#  'marymacgregor_tornbetweentwolovers',
#  'madonna_takeabow',
#  'houston,whitney_greatestloveofall',
#  'juicenewton_breakittomegently',
#  'thebyrds_eightmileshigh',
#  'ericclapton_promises',
#  'crosby,stills&nash_suite:judyblueeyes',
#  'inxs_needyoutonight',
#  'smokeyrobinson&themiracles_isecondthatemotion',
#  "cyndilauper_thegoonies'r'goodenough",
#  'radiohead_karmapolice',
#  'thehollies_longdarkroad',
#  'theyardbirds_shapesofthings',
#  'otown_allornothing',
#  'bonjovi_runaway',
#  'ocean_putyourhandinthehand',
#  'jacksonbrowne_boulevard',
#  'TRRFPKV149E3C83783',
#  'thekinks_betterthings',
#  'thekinks_tilltheendoftheday',
#  "raycharles_let'sgogetstoned",
#  'elvispresley_guitarman',
#  'flatt&scruggs_foggymountainbreakdown',
#  'TRTVJNY149E2E23D7B',
#  'abba_supertrouper',
#  'thejimihendrixexperience_purplehaze',
#  'queen_iwanttobreakfree',
#  'dion_abraham,martinandjohn',
#  'davedudley_sixdaysontheroad',
#  'littleriverband_happyanniversary',
#  "michaeljackson_ijustcan'tstoplovingyou",
#  'softcell_taintedlove',
#  'TRVQHUY149E3D23346',
#  "sonny&cher_acowboy'sworkisneverdone",
#  'thedramatics_heyyou!getoffmymountain',
#  'jeffbeck_peoplegetready(withrodstewart)',
#  'thebeatles_twoofus',
#  'roydrusky_threeheartsinatangle',
#  'glencampbell_rhinestonecowboy',
#  'bjthomas_hookedonafeeling',
#  'lesleygore_californianights',
#  'simon&garfunkel_cecilia',
#  'TRFBENP149E37D6299',
#  'henryflynt_celestialpower',
#  "thebeatles_i'maloser",
#  'TREDVCJ149E3753F8E',
#  'candistaton_youngheartsrunfree',
#  'therollingstones_beastofburden',
#  'thebeatles_glassonion(remaster)',
#  "judaspriest_you'vegotanotherthingcomin'",
#  'thebeatles_julia',
#  "thejgeilsband_justcan'twait",
#  "thebeatles_you'vegottohideyourloveaway",
#  'eltonjohn_candleinthewind',
#  'aerosmith_lastchild',
#  "buckowens_i'vegotatigerbythetail",
#  'debarge_timewillreveal(singleversion)',
#  'bobseger＆thesilverbulletband_againstthewind',
#  'woodstock_reason',
#  'badfinger_maybetomorrow(2010-remaster)',
#  'thebeatles_boys',
#  'TRUJVYL149E3C582D4',
#  "denver,john_annie'ssong",
#  'chicago_ifyouleavemenow',
#  'cyndilauper_girlsjustwanttohavefun',
#  'clapton,eric_wonderfultonight',
#  'ettajames_stopthewedding',
#  "thebeatles_everybody'sgotsomethingtohideexceptmeandmymonkey",
#  'thebeatles_runforyourlife',
#  'TRQUKHR149E32791CA',
#  'TRCGAAQ149E30D73B6',
#  'clarencecarter_tooweaktofight',
#  'thebeatles_imemine',
#  'bobbiegentry_odetobilliejoe',
#  'rem_everybodyhurts',
#  "johnnytillotson_i'maworriedguy",
#  'talkingheads_andshewas',
#  'billyidol_eyeswithoutaface',
#  'steviewonder_ifyoureallyloveme',
#  'coldplay_yellow',
#  'cheaptrick_surrender',
#  'thebeatles_yellowsubmarine',
#  'neildiamond_iamisaid',
#  'TRRUQGW149E32BC076',
#  'direstraits_romeoandjuliet',
#  'chicago_olddays',
#  'sting_fieldsofgold',
#  'anitabaker_givingyouthebestthatigot',
#  "cliffrichard_wedon'ttalkanymore",
#  'martyrobbins_iwalkalone',
#  'TRVMJYN149E3863E56',
#  "michaeljackson_wannabestartin'somethin'",
#  'thebeatles_tellmewhy',
#  'thepolice_roxanne',
#  "millivanilli_i'mgonnamissyou",
#  'crosby,stills&nash_southerncross',
#  'georgeharrison_crackerboxpalace(2004digitalremaster)',
#  'simon&garfunkel_mrsrobinson',
#  "rickspringfield_jessie'sgirl",
#  "chicago_feelin'strongereveryday",
#  'thepolice_spiritsinthematerialworld',
#  'thebeatles_rockyraccoon',
#  "ledzeppelin_d'yermak'er",
#  'TRCIBQC149E37C4155',
#  'thebeatles_08eightdaysaweek',
#  'earth,wind&fire_aftertheloveisgone',
#  "switch_there'llneverbe(singleversion)",
#  'fugees_killingmesoftly',
#  'davidbowie_spaceoddity(1999digitalremaster)',
#  'leannrimes_cantfightthemoonlight',
#  'cher_justlikejessejames',
#  'thebeatles_thingswesaidtoday',
#  'therighteousbrothers_unchainedmelody',
#  'stephaniemills_neverknewlovelikethisbefore',
#  'philcollins_twohearts',
#  'thebeatles_05-wildhoneypie',
#  'thebeatles_whilemyguitargentlyweeps',
#  "elvispresley_(marie'sthenameof)hislatestflame",
#  'kingjuanmutant_butyoulostallyourmemories',
#  'TROMDKK149E36F9DA0',
#  'thebeatles_help!',
#  'bonnieraitt_nickoftime',
#  'thebeatles_fornoone',
#  'generalpublic_tenderness',
#  "thebeatles_i'llcryinstead",
#  "cher_babydon'tgo",
#  'baycityrollers_saturdaynight',
#  'talkingheads_116-burningdownthehouse',
#  'zztop_lagrange',
#  'thebeatles_notasecondtime',
#  'bobseger_americanstorm(86)',
#  'thebeatles_helterskelter',
#  'rkelly_ibelieveicanfly',
#  'TRKWIWN149E3603415',
#  'deanmartin_iwill',
#  'thebeatles_rolloverbeethoven',
#  'neilsedaka_lovewillkeepustogether',
#  "rickspringfield_don'ttalktostrangers",
#  'thebeatles_nowhereman',
#  'therollingstones_doodoodoodoodoo(heartbreaker)',
#  'drhook_onlysixteen',
#  "arethafranklin_ohmeohmy[i'mafoolforyoubaby]",
#  'annemurray_couldihavethisdance(live)',
#  'thebeatles_andiloveher',
#  "tanyatucker_here'ssomelove",
#  'thebeatles_maggiemae',
#  "thebeatles_i'llbeback",
#  'TRLMCKC149E3133C1D',
#  'TRYIXOE127FAA17C99',
#  'stevewinwood_backinthehighlifeagain',
#  'paulmccartney_press(1993digitalremaster)',
#  "jimmyruffin_i'vepassedthiswaybefore(singleversion)",
#  'rodstewart_haveitoldyoulately',
#  'mariahcarey_anytimeyouneedafriend',
#  'thebeatles_goodnight',
#  "swingin'medallions_doubleshot(ofmybaby'slove)",
#  'jimmyclanton_justadream',
#  "dollyparton_babyi'mburnin'",
#  'weezer_elscorcho',
#  'brucespringsteen_myhometown',
#  'thebeatles_isawherstandingthere',
#  'therollingstones_goingtoago-go(live-2009re-mastereddigitalversion)',
#  'bobmarley&thewailers_nowoman,nocry',
#  'bonjovi_yougiveloveabadname',
#  'markymarkandthefunkybunch_goodvibrations',
#  'thenevillebrothers_tellitlikeitis',
#  'marvingaye_mercymercyme(theecology)',
#  "thebeatles_it'sonlylove",
#  'thebeatles_withinyouwithoutyou',
#  'marccohn_walkinginmemphis',
#  'carlcarlton_everlastinglove',
#  'crosby&nash_carryme',
#  'thewho_happyjack(alternatemonoversion)',
#  'theboxtops_crylikeababy(digitallyremastered:1996)',
#  'rickderringer_rockandrollhoochiekoo',
#  'thebeatles_ififell(64)',
#  'raycharles_eleanorrigby',
#  'jamesbrown_downandoutinnewyorkcity',
#  'TRONMEC149E3886747',
#  "chuckberry_reelin'androckin'",
#  'u2_withorwithoutyou',
#  'madonna_livetotell',
#  'TRBJDXP149E36B030A',
#  'bonnietyler_totaleclipseoftheheart',
#  'sly&thefamilystone_iwanttotakeyouhigher',
#  'billyidol_fleshforfantasy(1999digitalremaster)',
#  'georgebenson_babyworkout',
#  'thejgeilsband_freeze-frame',
#  'rayprice_forthegoodtimes',
#  'thebeatles_blackbird',
#  'thebeatles_dizzymisslizzy(65)',
#  'thebeatles_whatgoeson',
#  'queen_playthegame',
#  'drhook_themillionaire',
#  'thebeachboys_bluebirdsoverthemountain(digitallyremastered99)',
#  'natkingcole_unforgettable',
#  "bryanadams_whenyou'regone[withmelanie",
#  'jacksonbrowne_herecomethosetearsagain',
#  'dinahwashington_whereareyou',
#  'bread_if',
#  'littleriverband_helpisonitsway',
#  "mrsmiller_thesebootsaremadeforwalkin'(1997digitalremaster)",
#  "waylonjennings_themefromthedukesofhazzard(goodol'boys)",
#  "cannedheat_let'sworktogether",
#  'eltonjohn_whowearstheseshoes?',
#  "straycats_iwon'tstandinyourway(2000digitalremaster)",
#  'eltonjohn_philadelphiafreedom',
#  'santana_evilways',
#  "teddypendergrass_idon'tloveyouanymore",
#  'johndenver_seasonsoftheheart',
#  'garbage_onlyhappywhenitrains',
#  'thebeatles_girl',
#  'queen_hammertofall',
#  'thebeatles_allmyloving',
#  'abba_ihaveadream',
#  'beneking_amor',
#  'paulsimon_thesoundofsilence',
#  'thebeatles_mrmoonlight',
#  'littleriverband_theotherguy',
#  'shaggy_angel',
#  'goldenapes_thegreentearsofeliza',
#  'ericclapton_laydownsally',
#  'kennyrogers_lady',
#  'thebeatles_birthday',
#  'theeverlybrothers_ebonyeyes',
#  'peaches&herb_shakeyourgroovething',
#  'thetrammps_discoinferno',
#  'gloriagaynor_nevercansaygoodbye',
#  'dion_rubybaby',
#  "foghat_drivin'wheel(singleversion)",
#  'thebeatles_aharddaysnight(64)',
#  'anitabaker_caughtupintherapture',
#  'TRWAFST149E3DC68C3',
#  'queen_bohemianrhapsody',
#  'offspring_selfesteem',
#  "countbasieorchestra_goin'tochicagoblues",
#  'franksinatra_moonlightinvermont',
#  'TROFSOZ149E375AFC9',
#  'thebeatles_loveyouto',
#  'goldenearring_twilightzone',
#  'queensrÿche_silentlucidity(2000digitalremaster)',
#  'thebeatles_honeypie',
#  'johndenver_backhomeagain',
#  'gabrielle_rise',
#  "themusicexplosion_littlebito'soul",
#  'charlierich_lonelyweekends',
#  'TRKNYUQ149E33EFA7C',
#  'thebeatles_digit',
#  'queen_bicyclerace',
#  'thebeatles_actnaturally',
#  'jacksonbrowne_runningonempty',
#  'muse_unintended',
#  'littleriverband_reminiscing(singleedit)',
#  'therollingstones_missyou(2009re-mastereddigitalversion)',
#  'charlierich_averyspeciallovesong',
#  'billysquier_thestroke(live)',
#  'enya_tea-housemoon',
#  'everclear_santamonica',
#  'thenittygrittydirtband_makealittlemagic',
#  'thebeatles_michelle',
#  'creedenceclearwaterrevival_badmoonrising',
#  'queen_wewillrockyou',
#  'creedenceclearwaterrevival_proudmary',
#  "millivanilli_babydon'tforgetmynumber(subwaymix)",
#  'paulsimon_youcancallmeal',
#  'fontellabass_rescueme(singleversion)',
#  'joeanderson_withalittlehelpfrommyfriends',
#  'thebeatles_pleasepleaseme',
#  'jirímazánek_chakrabalancing',
#  'thesupremes_floyjoy',
#  'TRFYTTA149E386F073',
#  "thebeatles_octopus'sgarden",
#  "bobbywomack_that'sthewayifeelabout'cha",
#  'TRCZCXZ149E3E2FC6E',
#  'patbenatar_promisesinthedark',
#  'thebeatles_acrosstheuniverse',
#  'TRTZMDA149E34EE322',
#  'TRIYMAA149E38CDC1E',
#  'ritacoolidge_thewayyoudothethingsyoudo',
#  'baltimora_tarzanboy(originalversion)',
#  'TRZFLMI149E3D9B82D',
#  'TREOWBD149E333539D',
#  "celinedion_it'sallcomingbacktomenow",
#  'brendalee_allaloneami',
#  'crosby,stills,nash&young_teachyourchildren',
#  'the5thdimension_ificouldreachyou',
#  'nodoubt_justagirl',
#  'therollingstones_notfadeaway(live-2009re-mastereddigitalversion)',
#  'thebeatles_beingforthebenefitofmrkite!',
#  'pinkfloyd_money',
#  'harrychapin_sundaymorningsunshine',
#  'sixpencenonethericher_kissme',
#  'eddieholland_jamie',
#  'TRACGVT149E3B9BE3F',
#  'TRTAYJK149E3E09AA6',
#  'creedenceclearwaterrevival_haveyoueverseentherain-',
#  'billyswan_icanhelp',
#  'corneliusbrothers&sisterrose_treatherlikealady',
#  'TRMLNPR149E35EF902',
#  'thehollies_carrieanne',
#  'redbone_comeandgetyourlove',
#  'themeters_look-kapypy',
#  'thebeatles_anytimeatall',
#  'enya_silverinches',
#  'neildiamond_shilo',
#  "alano'day_undercoverangel(originalsingleversion)",
#  'elvispresley_shethinksistillcare',
#  "thecrystals_he'sarebel",
#  'eltonjohn_sorryseemstobethehardest',
#  'thebeatles_fixingahole',
#  'lookingglass_brandy',
#  'gladysknight_bestthingthateverhappenedtome',
#  'brendalee_comingonstrong',
#  'queen_wearethechampions',
#  "bonjovi_i'llbethereforyou",
#  'thealanparsonsproject_eyeinthesky',
#  'orbison,roy_oh,prettywoman',
#  'thebeatles_money',
#  'neildiamond_sweetcaroline',
#  'therollingstones_waitingonafriend',
#  'orbison,roy_bluebayou',
#  'boyziimen_motownphilly(originalversion)',
#  'dido_thankyou',
#  'johndenver_rockymountainhigh',
#  'bryanadams_(everythingido)idoitfor',
#  'TRUEMYZ149E326FAD5',
#  "dottiewest_alessoninleavin'",
#  "thechiffons_he'ssofine",
#  "rodstewart_twistin'thenightaway",
#  'elvispresley_mywishcametrue',
#  "queen_don'tstopmenow",
#  'backstreetboys_showmethemeaningofbeingl',
#  'natalieimbruglia_torn',
#  'thebeatles_pennylane',
#  'clarencecarter_patches',
#  'davidbowie_bluejean(1999digitalremaster)',
#  'aguilera,christina_genieinabottle',
#  "canyoudigit_15_ican'tstandtherain",
#  'steviewonder_thatgirl',
#  'theyoungbloods_gettogether',
#  'queen_akindofmagic',
#  'jackson5_iwantyouback',
#  'thejgeilsband_onelastkiss(2006digitalremaster)',
#  'wilsonpickett_ifoundatruelove',
#  'TRBAFVO149E33A9195',
#  'TRFQEUW149E3434096',
#  'TRGQBPW149E330FAC7',
#  'colormebadd_iadoremiamor',
#  'thecure_justlikeheaven',
#  'dion_loverswhowander',
#  'jimmycliff_wonderfulworld,beautifulpeople',
#  'barbrastreisand_funnygirl',
#  'theallmanbrothersband_straightfromtheheart',
#  "firehouse_don'ttreatmebad(live)",
#  'thebeatles_holdmetight',
#  "blacksabbath_warpigsluke'swall",
#  'theronettes_bemybaby',
#  'bobbelden_armsoforion',
#  "eltonjohn_iguessthat'swhytheycalli",
#  'cultureclub_karmachameleon(2002-remaster)',
#  "thebeatles_maxwell'ssilverhammer",
#  'TRJMAJM149E3BAFE12',
#  'billyidol_whitewedding',
#  'elvispresley_judy',
#  'grahamnash_chicagowecanchangetheworld',
#  'thebeatles_askmewhy',
#  "thebeatles_i'mlookingthroughyou",
#  'therollingstones_timeisonmyside',
#  'quarterflash_hardenmyheart(single)',
#  'robbase&dje-zrock_ittakestwo',
#  'chriskenner_landofa1,000dances',
#  'cyndilauper_allthroughthenight',
#  'cyndilauper_idroveallnight',
#  'TRTFZGV149E3EC9AC3',
#  'thebeatles_polythenepam',
#  'celinedion_myheartwillgoon',
#  'incubus_drive',
#  'meatloaf_youtookthewordsrightoutofmymouth((hotsummernights)livetakenfromstorytellers)',
#  'denver,john_mysweetlady',
#  'morissette,alanis_uninvited',
#  'thebeatles_thenightbefore(65)',
#  'georgeharrison_allthoseyearsago(2004digitalremaster)',
#  'crosby,stills,nash&young_gotitmade(unreleasedliveversion)',
#  'glencampbell_wichitalineman(2003digitalremaster)',
#  "carlysimon_you'resovain",
#  "thebeatles_babyyou'rearichman",
#  'queen_sevenseasofrhye',
#  'mariahcarey_hero',
#  'isaachayes_doyourthing',
#  'TRPXXCL149E3E6A86C',
#  'thebeatles_here,thereandeverywhere(66)',
#  'cliffrichard_carrie(2001digitalremaster)',
#  "lesleygore_youdon'townme",
#  'jamestaylor_countryroad',
#  'mikeoldfield_moonlightshadow',
#  'TREXPPD149E344AB31',
#  'vanmorrison_browneyedgirl',
#  'rock&hyde_dirtywater',
#  'fatsdomino_iwanttowalkyouhome',
#  'genesis_abacab(live)(1994digitalremaster)',
#  'thenittygrittydirtband_buyformetherain(67)',
#  "thebeatles_whydon'twedoitintheroad",
#  'selena_dreamingofyou',
#  "eagles_lyin'eyes",
#  'thecowsills_hair',
#  'roxette_thelook',
#  'rodbernard_thisshouldgoonforever',
#  'thebeatles_thefoolonthehill(remaster)',
#  'thebeatles_shesaidshesaid',
#  'TRPTSTW149E2DFBB05',
#  'thepointersisters_jump(formylove)',
#  'eltonjohn_thebitchisback',
#  'thebeatles_revolution1',
#  'heart_crazyonyou',
#  'gordonlightfoot_beautiful',
#  'abba_fernando',
#  'vanhalen_givetolive(liveversion)',
#  "cultureclub_i'lltumble4ya",
#  'joanbaez_therebutforfortune',
#  'sting_ifyoulovesomebodysetthemfree',
#  'billyidol_hotinthecity',
#  "theeverlybrothers_that'soldfashioned",
#  'thebeatles_yesterday',
#  'tomthall_ilove',
#  'thesupremes_stonedlove',
#  'eurythmics_sweetdreams(aremadeofthis',
#  'TRPEKMS149E34781B4',
#  'player_babycomeback',
#  'TRHEWTX149E3B0DFC6',
#  'eagles_thebestofmylove',
#  'commodores_lady(youbringmeup)',
#  'garyusbonds_quartertothree',
#  'TREIEVN149E33F4F25',
#  'glencampbell_galveston(2003digitalremaster)',
#  "engelberthumperdinck_afterthelovin'",
#  'dion_thislittlegirl',
#  'TRPAQCL149E3F1FCAA',
#  "jan&dean_sidewalksurfin'",
#  "thebeachboys_surfin'safari",
#  'oftheunitedstatesofameri_lump',
#  'genesis_intoodeep',
#  "bodiddley_youcan'tjudgeabookbyit'scover",
#  'thebeachboys_kokomo',
#  'jamesbrown_think',
#  'sting_allthistime',
#  'creedenceclearwaterrevival_iputaspellonyou',
#  'coreyhart_inyoursoul',
#  'nsync_byebyebye',
#  'chicago_makemesmilenowmorethanever',
#  'thedoors_lightmyfire',
#  "ronniemilsap_iwouldn'thavemisseditfortheworld",
#  'thebeatles_iwill',
#  "johndenver_annie'ssong",
#  'hall&oates_kissonmylist',
#  "thebeatles_sgtpepper'slonelyheartsclubband(reprise)",
#  'bobseger＆thesilverbulletband_likearock',
#  'chicago_anotherrainydayinnewyorkcity',
#  "thechiffons_sweettalkin'guy",
#  'enya_stormsinafrica',
#  'paulmccartney_mylove',
#  'thebeatles_gottogetyouintomylife',
#  'georgeharrison_gotmymindsetonyou(2004digitalremaster)',
#  'theeverlybrothers_walkrightback',
#  'janisjoplin_kozmicblues',
#  'rdeantaylor_indianawantsme',
#  'michaeljohnson_almostlikebeinginlove',
#  'joel,billy_pianoman',
#  'therollingstones_honkytonkwoman',
#  'a-ha_takeonme',
#  'thebeatles_inmylife',
#  'queen_iwantitall',
#  'brendalee_asusual',
#  'corrs,the_onenight',
#  'neildiamond_songsungblue',
#  "enya_flora'ssecret",
#  'simon&garfunkel_elcondorpasa(ificould)',
#  "billysquier_don'tsayyouloveme",
#  'alicecooper_heystoopid',
#  'thebeachboys_godonlyknows',
#  'petshopboys_lovecomesquickly(2001digitalremaster)',
#  'bluecheer_summertimeblues',
#  'arethafranklin_ineverlovedaman(thewayiloveyou)',
#  'TRHFQYU149E36951C9',
#  "jamesbrown_idon'tmind",
#  'ike&tinaturner_iwannatakeyouhigher',
#  'cheaptrick_stopthisgame',
#  "petshopboys_wherethestreetshavenoname(ican'ttakemyeyesoffyou)(2003-remaster)",
#  "thebeatles_sgtpepper'slonelyheartsclubband",
#  "thebeachboys_stillcruisin'",
#  "thepointersisters_he'ssoshy",
#  'jimmygilmerandthefireballs_sugarshack',
#  'maxfrost_shapeofthingstocome',
#  'rareearth_getready',
#  'bobbybare_detroitcity',
#  "ritacoolidge_we'reallalone",
#  'thebeatles_lucyintheskywithdiamonds',
#  'thebeatles_iwanttotellyou',
#  'kansas_dustinthewind',
#  "thebeatles_don'tbotherme",
#  'thebeatles_ifineededsomeone',
#  'pureprairieleague_amie(remasteredjanuary1992)',
#  'michaeljackson_humannature',
#  'juicenewton_queenofhearts',
#  'theosmonds_onebadapple(71)',
#  'jeffersonstarship_countonme',
#  'oliver_goodmorningstarshine',
#  'survivor_eyeofthetiger',
#  'tee-set_mabelleamie',
#  'freddyfender_livingitdown',
#  'eddierabbitt_ilovearainynight',
#  'michaelsembello_maniac',
#  'stevieb_becauseiloveyou(thepostmansong)(90)',
#  "raycharles_cryin'time",
#  'hueylewis&thenews_iwantanewdrug(1999-remaster)',
#  'dion_lovecametome',
#  'genesis_invisibletouch',
#  "nataliecole_i'vegotloveonmymind",
#  'ericclapton_willieandthehandjivegetready',
#  'reospeedwagon_timeformetofly(2000liveatriverportamphitheatre,stlouis,mo)',
#  'theshirelles_willyoulovemetomorrow',
#  'nsync_thisipromiseyou',
#  'denver,john_takemehome,countryroads',
#  'genesis_tonight,tonight,tonight(2007remasteredversion)',
#  "barrywhite_you'rethefirst,thelast,myeverything",
#  'ericcarmen_hungryeyes',
#  'TRVKORV127FA621F55',
#  "ike&tinaturner_it'sgonnaworkoutfine",
#  'thebeatles_yerblues',
#  'thebeatles_withalittlehelpfrommyfriends',
#  'thebeatles_andyourbirdcansing',
#  'thebeatles_everylittlething',
#  'dion_runaroundsue',
#  'simonandgarfunkel_theboxer',
#  'spicegirls_2become1',
#  'thebeatles_lovemedo',
#  'ledzeppelin_trampledunderfoot',
#  'brucechannel_hey!baby',
#  "themiracles_mightygoodlovin'",
#  'gladysknight&thepips_ifiwereyourwoman',
#  'michaeljackson_beatit-singleversion',
#  "therollingstones_it'sonlyrock'n'roll(butilikeit)",
#  'thebeatles_iamthewalrus',
#  'jackson5_dancingmachine',
#  'metallica_nothingelsematters',
#  'marvingaye_ificouldbuildmywholeworldaroundyou',
#  'thebeatles_thelongandwindingroad',
#  'thejohnnymannsingers_heartfullofsoul(1997digitalremaster)',
#  'ettajames_woulditmakeanydifferencetoyou',
#  'thepolice_everylittlethingshedoesismagic',
#  "gladysknight&thepips_babydon'tchangeyourmind",
#  'abba_knowingme,knowingyou',
#  'michaeljackson_maninthemirror',
#  'TRLLTGA149E3BC27EE',
#  'clapton,eric_tearsinheaven',
#  'enya_watermark',
#  'sarahmclachlan_"adia"bysarahmclachlan',
#  "cliffrichard_daddy'shome(live)(2001digitalremaster)",
#  'bbking_howbluecanyouget?',
#  'raycharles_(nighttimeis)therighttime',
#  'johnnyhorton_thebattleofneworleans',
#  "paulmccartney_maybei'mamazed",
#  'TRVSDOO149E381C668',
#  'thebeatles_tilltherewasyou',
#  'ericclapton_foreverman',
#  'genepitney_townwithoutpity',
#  'TROXQFJ149E386AAE8',
#  'TRETREY149E3ABF474',
#  'sirjuanmutant_9loons',
#  'procolharum_awhitershadeofpale',
#  'thebeatles_thinkforyourself',
#  "thebeatles_baby'sinblack",
#  'backstreetboys_iwantitthatway',
#  'steppenwolf_borntobewild',
#  'isaachayes_thelookoflove',
#  'bobseger_evennow',
#  "thebeatles_iwantyou(she'ssoheavy)",
#  'patbenatar_fireandice',
#  'grandfunkrailroad_walklikeaman(youcancallmeyourman)(2002digitalremaster)',
#  'TRVFRRU149E3560CDE',
#  'thebeachboys_inmyroom',
#  'bachman-turneroverdrive_heartaches',
#  'elvispresley_myboy',
#  'billyjoel_justthewayyouare',
#  'morissette,alanis_ironic',
#  'oasis_wonderwall',
#  'thebeatles_obladi,oblada',
#  "thebeatles_babyit'syou",
#  'therollingstones_tumblingdice',
#  'TRNIWPE149E35E9B6D',
#  'rodstewart_sailing',
#  "thestaplesingers_i'lltakeyouthere",
#  'TRKZUNB149E2E31D84',
#  'sarahmclachlan_"angel"bysarahmclachlan',
#  '3doorsdown_kryptonite',
#  'newtonjohn,olivia_ihonestlyloveyou',
#  'TRBZFAA149E3EEDCEB',
#  'thebeatles_cometogether',
#  "kriskristofferson_lovingherwaseasier(thananythingi'lleverdoagain)",
#  'themusicmachine_thepeopleinme',
#  'thebeachboys_sailon,sailor',
#  'pinkfloyd_anotherbrickinthewall,pt2(2011-remaster)',
#  '"brother"jackmcduff_themefromelectricsurfboard',
#  "smokeyrobinson_cruisin'",
#  'vanhalen_jump',
#  'level42_somethingaboutyou(singleversion)',
#  "smokeyrobinson&themiracles_idon'tblameyouatall",
#  'bettemidler_therose',
#  'ub40_thewayyoudothethingsyoudo',
#  'queen_saveme',
#  'acdc_haveadrinkonme',
#  'hall&oates_richgirl',
#  'thebeatles_iwannabeyourman',
#  'thebeatles_dearprudence',
#  'brendalee_dumdum',
#  'thebeatles_getback(nonhitalbumversion)',
#  'steviewonder_superstition',
#  'thebeatles_psiloveyou',
#  'cheaptrick_dreampolice',
#  'toddrundgren_adreamgoesonforever',
#  'leosayer_youmakemefeellikedancing(single)',
#  'weezer_islandinthesun',
#  'paulanka_lovemewarmandtender',
#  'johnnycash_thewaysofawomaninlove',
#  "smokeyrobinson&themiracles_baby,babydon'tcry",
#  'nenehcherry_kissesonthewind',
#  'kiss_rocketride',
#  'irmathomas_iwishsomeonewouldcare',
#  'solomonburke_ifyouneedme',
#  'thebeatles_sexysadie',
#  "theisleybrothers_it'syourthing",
#  'googoodolls_blackballoon',
#  "kennyrogers_idon'tneedyou",
#  "thebeatles_i'vejustseenaface",
#  "elvispresley_ireallydon'twanttoknow",
#  'theboys_dialmyheart',
#  'enya_eveningfalls',
#  'arthurconley_sweetsoulmusic',
#  'deanmartin_everybodylovessomebody',
#  "rickymartin_livin'lavidaloca",
#  'cyndilauper_shebop',
#  'freddyfender_secretlove',
#  'richie,lionel_endlesslove',
#  'TROYRFP149E3AF313A',
#  'TROYQYU149E3A124EC',
#  'simonandgarfunkel_bridgeovertroubledwater',
#  'boston_amanda',
#  'loslobos_willthewolfsurvive?',
#  'thepolice_everybreathyoutake',
#  'TRYVIGS149E360A5A8',
#  'wednesday_lastkiss(74)',
#  'commodores_easy',
#  'kennyrogers_youdecoratedmylife',
#  'TRTCDTH149E3152ABD',
#  'ritacoolidge_fever',
#  'theoakridgeboys_elvira(singleversion)',
#  'rush_thespiritofradio',
#  'duranduran_allshewantsis',
#  'stevens,cat_morninghasbroken',
#  'floydcramer_lastdate',
#  'elvispresley_askme',
#  'thebeatles_oneafter909',
#  'thebeatles_backintheussr',
#  "otisredding_i'vebeenlovingyoutoolong",
#  'chicodebarge_talktome',
#  'kaoma_lambada',
#  'thecontours_doyouloveme',
#  'TRXWOYW149E325CE82',
#  'marthareeves&thevandellas_nowheretorun',
#  'thejgeilsband_lookingforalove',
#  'therascals_peoplegottobefree',
#  'TRRZBMF149E34DF030',
#  'TRHOOHK149E362E7B2',
#  'jan&dean_thelittleoldlady(frompasadena)',
#  'traciespencer_thishouse',
#  'urbandancesquad_deepershadeofsoul',
#  'denver,john_poems,prayersandpromises',
#  'elvispresley_theregoesmyeverything',
#  'littlejoey&theflips_bongostomp',
#  'jan&dean_theanaheim,azusaandcucamongasewingcircle,bookreviewandtimingassociation',
#  'thebeatles_eightdaysaweek',
#  'live_ialone',
#  'straycats_rockthistown',
#  'TRDDWYV149E3F228DB',
#  'dion&thebelmonts_whereorwhen',
#  'elvispresley_myway',
#  'bobdylan_gottaservesomebody',
#  'anitabaker_sweetlove',
#  'tommyjames&theshondells_crystalbluepersuasion',
#  'templeofthedog_hungerstrike',
#  'TRBKNSX149E2E1F89F',
#  "stevemillerband_rock'n'me",
#  'TRWWOOL149E3366289',
#  'thepsychedelicfurs_prettyinpink(fromtheoriginalmotionpicturesoundtrack)',
#  'chuckberry_almostgrown',
#  'thebeatles_littlechild',
#  'TRKCBKD149E3C4EEAC',
#  'TRWTXNB149E3D653D2',
#  'TRXDZWS149E33441A7',
#  'littleriverband_wetwo(24-bitremastered99)(1999digitalremaster)',
#  'thebeatles_oh!darling',
#  'charlierich_behindcloseddoors',
#  'thebeatles_drivemycar',
#  'bobseger_oldtimerock&roll',
#  'thebeatles_youregonnalosethatgirl',
#  'thebeatles_pleasemisterpostman',
#  'cranberries,the_zombie',
#  'annemurray_daydreambeliever',
#  'aguilera,christina_whatagirlwants',
#  "johnnytillotson_jimmy'sgirl",
#  'marvingaye_ittakestwo',
#  "thebeatles_i'monlysleeping",
#  'thebeatles_theword',
#  'jimmybuffett_comemonday',
#  'TRAVBNX149E3F1BDEB',
#  'TRQZUHU127F8D2ED7A',
#  "yvonneelliman_ifican'thaveyou",
#  'stevemillerband_thejoker',
#  'tracychapman_babycaniholdyou',
#  'thebeatles_01noreply',
#  'abba_onandonandon',
#  'thebeatles_devilinherheart',
#  "thebeatles_idon'twanttospoiltheparty(65)",
#  'johnnytillotson_outofmymind',
#  'thetemptations_iwishitwouldrain',
#  'TRNLAON149E3C7A10A',
#  'TRYFCBP149E38AA0A0',
#  "brucespringsteen_i'mgoin'down",
#  "thebeatles_alli'vegottodo",
#  'thebeatles_ineedyou',
#  'bobbywomack_sweetcaroline(goodtimesneverseemedsogood)',
#  'thebeatles_hellogoodbye',
#  'thefalcons_ifoundalove',
#  'nirvana_smellsliketeenspirit',
#  "billypreston_withyoui'mbornagain",
#  'elvispresley_onenight',
#  'ginovannelli_blackcars',
#  'thebeatles_doyouwanttoknowasecret',
#  'thebeatles_29-revolution9',
#  "simon&garfunkel_fakin'it",
#  "billwithers_ain'tnosunshine",
#  'eagles_alreadygone',
#  'kennyrogers_scarletfever',
#  'billyidol_rebelyell',
#  "millivanilli_girlyouknowit'strue",
#  'robertjohn_sadeyes',
#  'dollyparton_startingoveragain',
#  'paulsimon_bridgeovertroubledwater',
#  'jamesbrown_igotyou(ifeelgood)',
#  'thebeatles_ishouldhaveknownbetter',
#  'TRJGRAC149E3A0A32B',
#  'gratefuldead_sugarmagnolia',
#  'thebuckinghams_kindofadrag',
#  'jimmyruffin_standbyme',
#  "glencampbell_it'sonlymakebelieve",
#  "queen_you'remybestfriend",
#  'yazoo_situation(12"remix)',
#  "sammyhagar_ican'tdrive55",
#  "jermainejackson_let'sgetserious-singleversion",
#  "joel,billy_she'salwaysawoman",
#  'therembrandts_someone',
#  'paulrevereandtheraiders_kicks',
#  'thebeatles_tomorrowneverknows',
#  'TRDSBAH149E37B923E',
#  "thebeatles_youwon'tseeme",
#  'bryanadams_heaven',
#  'gordonhempton_asia:mistyisle(fullalbuminonetrack)',
#  'ginovannelli_hurtstobeinlove',
#  'fivemanelectricalband_absolutelyright',
#  'beastieboys_brassmonkey',
#  'bobmarley&thewailers_jamming',
#  'jimmyjones_handyman',
#  'enya_onlytime',
#  'jamesbrown_mythang',
#  "natkingcole_ramblin'rose",
#  'queen_somebodytolove',
#  "boston_feelin'satisfied",
#  'abba_thankyouforthemusic',
#  'chubbychecker_thetwist',
#  'donnafargo_superman',
#  'brendalee_everybodylovesmebutyou',
#  'thebeatles_eleanorrigby',
#  'tinaturner_thebest',
#  'TRZRAGD149E37275D3',
#  'cher_ificouldturnbacktime',
#  'arethafranklin_chainoffools',
#  'jfrankwilson&thecavaliers_lastkiss',
#  'georgeharrison_blowaway(2004digitalremaster)',
#  'georgeharrison_thissong(2004digitalremaster)',
#  'cliffrichard_devilwoman(2001digitalremaster)',
#  'lynyrdskynyrd_sweethomealabama',
#  'rickjames_superfreak(part1)(1981singleversion)',
#  'fatsdomino_bemyguest',
#  'royorbison_crysoftlylonelyone',
#  'TRYMOQH149E3644AD2',
#  'bbking_thethrillisgone',
#  "bryanadams_summerof'69",
#  "thebeatles_she'sleavinghome",
#  'lindaronstadt_whenwillibeloved',
#  'lavernbaker_seeseerider',
#  'thebeatles_something',
#  "jonimitchell_(you'resosquare)baby,idon'tcare",
#  'TRMOOXL149E3A2FFCE',
#  'TRCPMTN149E3BD5787',
#  'louisarmstrong_hello,dolly!',
#  'gabriel,peter_steam',
#  'donnasummer_lastdance',
#  'aerosmith_fallinginlove',
#  "thebeatles_whatyou'redoing",
#  'thebeatles_hermajesty',
#  'philcollins_iwishitwouldraindown',
#  'billyjoel_pressure',
#  'gregkihn_lucky',
#  'whitesnake_hereigoagain',
#  'thebeatles_rockandrollmusic(64)',
#  'ironbutterfly_in-a-gadda-da-vida',
#  'queen_goodold-fashionedloverboy',
#  'bachman-turneroverdrive_rollondownthehighway',
#  'TRAPEUF149E3BF4C4C',
#  'sly&thefamilystone_hotfuninthesummertime',
#  'poison_unskinnybop',
#  "hanksnow_i'vebeeneverywhere",
#  'dongibson_seaofheartbreak',
#  'patbenatar_littletoolate',
#  'enya_wildchild',
#  'the5thdimension_onelessbelltoanswer',
#  'rickderringer_rightplace,wrongtime',
#  'britneyspears_babtonemoretime',
#  "thebeatles_honeydon't",
#  'thebeatles_goldenslumbers',
#  'doubleexposure_10percent',
#  'TRZMYAA149E2C43730',
#  'deeppurple_smokeonthewater',
#  'evelyn"champagne"king_i\'minlove',
#  "badcompany_rock'n'rollfantasy",
#  'thebeatles_09wordsoflove',
#  'eltonjohn_yoursong',
#  'johndenver_somedaysarediamonds(somedaysarestone)',
#  'cyndilauper_truecolors',
#  'TRUCFWP149E3DF4075',
#  'thebeatles_lovelyrita',
#  'TRWKTXY149E2B9CD1E',
#  'TRVVIUU149E2E41FE9',
#  'thefabulousthunderbirds_tuffenuff',
#  'sagittarius_myworldfelldown',
#  'TRUEMQB149E3465DA5',
#  'blacksabbath_ironman',
#  'patbenatar_heartbreaker',
#  'elvispresley_ificandream',
#  'brendalee_heartinhand',
#  'mariahcarey_onesweetday',
#  "nodoubt_don'tspeak",
#  'youngmc_bustamove',
#  'williemitchell_20-75',
#  'lavernbaker_icriedatear',
#  'jonimitchell_bigyellowtaxi(2007)',
#  'duranduran_istheresomethingishouldknow',
#  'berthatillman_ohmyangel',
#  'thebeatles_strawberryfieldsforever',
#  'allsaints_neverever',
#  'TROUCLD149E3E29CEF',
#  'thebeatles_foryoublue',
#  'creedenceclearwaterrevival_cottonfields',
#  "thebeatles_itwon'tbelong",
#  "georgebenson_breezin'",
#  ...]
