# %%
import jams

import os

# Iterate over files in data/chord_data_1217/audio

# %%
jam = jams.load('data/chord_data_1217/references_v2/TRYJNXA127F8DD6B06.jams')
print(jam)
# Out:
# {
#   "annotations": [
#     {
#       "annotation_metadata": {
#         "curator": {
#           "name": "Tae Min Cho",
#           "email": "tmc323@nyu.edu"
#         },
#         "annotator": {},
#         "version": "1.0",
#         "corpus": "MARL-Chords",
#         "annotation_tools": "Sonic Visualizer",
#         "annotation_rules": "",
#         "validation": "TODO",
#         "data_source": "Undergraduate music students"
#       },
#       "namespace": "chord",
#       "data": [
#         {
#           "time": 0.0,
#           "duration": 3.717,
#           "value": "N",
#           "confidence": 1.0
#         },
#         {
#           "time": 3.717,
#           "duration": 1.6360000000000001,
#           "value": "E:9",
#           "confidence": 1.0
#         },
#         {
#           "time": 5.353000000000001,
#           "duration": 1.782,
#           "value": "G:maj",
#           "confidence": 1.0
#         },
#         {
#           "time": 7.135000000000001,
# ...

# %%
# Load the file data/chord_data_1217/audio/filelist.txt
with open('data/chord_data_1217/audio/filelist.txt', 'r') as f:
    # Iterate over the lines in the file
    lines = f.readlines()
    print(len(lines))
# Out:
# 1217
